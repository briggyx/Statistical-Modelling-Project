# %%
import sqlite3
from sqlite3 import Error
import pandas as pd
import os 
import re
import requests
import numpy as np
from collections import Counter
from math import nan
from matplotlib import pyplot as plt
from statsmodels import api as sm
from sys import exit, stderr
from scipy.stats import linregress

# %% [markdown]
# # Database

# %% [markdown]
# ## Put all your results in an SQLite3 database (remember, SQLite stores its databases as files in your local machine - make sure to create your database in your project's data/ directory!)

# %%
# Connect to SQLite database in Python 
def create_connection(path):
    connection = None
    try:
        connection = sqlite3.connect(path)
        print("Connection to SQLite DB successful")
    except Error as e:
        print(f"The error '{e}' occurred")

    return connection

# %%
path = '../FinalData/SFbikestations_POI_sql_database.sqlite'
connection = create_connection(path)
# Out:
# Connection to SQLite DB successful

# %%
# This code defines a function called "execute_query" that allows for executing SQL queries in SQLite
# It uses the cursor's .execute() method to execute the query
# The function takes in two arguments: the connection object and a query strin
# The query string is passed to the .execute() method and can contain any type of SQL query, including creating tables
def execute_query(connection, query):
    cursor = connection.cursor()
    try:
        cursor.execute(query)
        connection.commit()
        print("Query executed successfully")
    except Error as e:
        print(f"The error '{e}' occurred")

# %%
create_data_by_business_table = """
CREATE TABLE IF NOT EXISTS data_by_business(
  ID INTEGER PRIMARY KEY AUTOINCREMENT, 
  POI_Query TEXT NOT NULL, 
  POI_Categories TEXT NOT NULL, 
  POI_Name VARCHAR NOT NULL, 
  POI_Address VARCHAR NOT NULL,
  POI_Mean_Bayesian_Adj_Rating_Norm FLOAT NOT NULL,
  POI_FSQ_Bayesian_Adj_Rating FLOAT,
  POI_FSQ_Rating FLOAT,
  POI_FSQ_Num_Ratings INT, 
  POI_Yelp_Bayesian_Adj_Rating_Norm FLOAT,
  POI_Yelp_Bayesian_Adj_Rating FLOAT, 
  POI_Yelp_Rating FLOAT,
  POI_Yelp_Num_Ratings FLOAT
  
);
"""

execute_query(connection, create_data_by_business_table)
# Out:
# Query executed successfully

# %%
# Populate the new table with values from the .csv file 
DataByBusiness = pd.read_csv("../final_data/DataByBusiness.csv")
DataByBusiness.to_sql("data_by_business", connection, if_exists='replace', index=False)
# Out:
# 9327

# %%
# Check to see if the SQLite table matches the orginal .csv 
# They both have the same number of rows, and the first and last rows match 
cursor = connection.cursor()
cursor.execute('SELECT * from data_by_business')
 
# Fetch all records as list of tuples
SF_POI_by_business = cursor.fetchall()
 
# Display result 
for row in SF_POI_by_business:
    # show row
    print(row)
# Out:
# ('Restaurants', 'French, Italian, Spanish', ' Ct', '5478 College Ave Oakland, CA 94618', 0.6481617025147504, None, None, None, None, 0.6481617025147504, 3.980772951994084, 4.0, 1387.0)
# ('Restaurants', 'Greek, Mediterranean, Salad', '$5 Salad', '60 Morris St San Francisco, CA 94103', 0.6081364049845138, None, None, None, None, 0.6081364049845138, 3.891520400662619, 2.5, 3.0)
# ('Restaurants', 'Japanese Curry, Ramen', '$6 Dollar Bowl Shop', '90 Charter Oak Ave San Francisco, CA 94124', 0.6514234763731033, None, None, None, None, 0.6514234763731033, 3.988046392959872, 4.5, 57.0)
# ('Restaurants', 'Burgers, Fast Food', '1 800 Burgers', '5333 Adeline St Oakland, CA 94608', 0.6012197140711179, None, None, None, None, 0.6012197140711179, 3.87609684733799, 1.5, 4.0)
# ('Bars', 'Seafood Markets, Wine Bars', '1 Fish 2 Fish Market', '141 Gough St San Francisco, CA 94102', 0.6163831621833562, None, None, None, None, 0.6163831621833562, 3.90990987346171, 5.0, 2.0)
# ('Funeral Homes', 'Funeral Home', '1 Hour Marriage', '600 California St, San Francisco, CA 94108', None, None, None, None, None, None, None, None, None)
# ('Bars', 'Lounge', '1 Presidio', '1 Presidio Ave, San Francisco, CA 94115', None, None, None, None, None, None, None, None, None)
# ('Restaurants', 'American Restaurant, Café, Sandwich Restaurant', '10th & Wood', '945 Wood St (10th), Oakland, CA 94607', 0.6263489520067325, 0.613622985749762, 8.17810831141772, 8.2, 61.0, 0.639074918263703, 3.960510299925304, 4.0, 498.0)
# ('Bars', 'Art Galleries, Bars, Venues & Event Spaces', '111 Minna Gallery', '111 Minna St San Francisco, CA 94105', 0.4889792114887334, None, None, None, None, 0.4889792114887334, 3.6258113570018873, 3.5, 763.0)
# ('Bars', 'Bar', '1120 - The Kickit', '1120 11th Ave (east 12 st), Oakland, CA 94606', None, None, None, None, None, None, None, None, None)
# ('Bars', 'Bars', '1217 Sutter', '1217 Sutter St San Francisco, CA 94109', 0.6149725982548618, None, None, None, None, 0.6149725982548618, 3.90676445201071, 5.0, 1.0)
# ('Restaurants', 'Breakfast & Brunch, Cafes', '1275 Cafe', '1275 Market St San Francisco, CA 94103', 0.6136786099009136, None, None, None, None, 0.6136786099009136, 3.9038789828422216, 4.0, 1.0)
# ('Restaurants', 'Bagels, Burgers, Cafes', '130 Cafe', '130 Frank H Ogawa Plz Oakland, CA 94612', 0.6156941907664831, None, None, None, None, 0.6156941907664831, 3.908373533683001, 4.0, 18.0)
# ('Restaurants', 'American (Traditional), Breakfast & Brunch, Creperies', '1428 HAIGHT Patio Cafe & Crepery', '1428 Haight St San Francisco, CA 94117', 0.6383992992978863, None, None, None, None, 0.6383992992978863, 3.959003734824033, 4.0, 467.0)
# ('Restaurants', 'American Restaurant, Café, Creperie', '1428 Haight', '1428 Haight St (at Masonic Ave), San Francisco, CA 94117', 0.3848892910508146, 0.3848892910508146, 7.559678084343729, 6.7, 128.0, None, None, None, None)
# ('Bars, Restaurants', 'American Restaurant, Cocktail Bar, Tapas Restaurant', '15 Romolo', '15 Romolo Pl (btwn Fresno St & Broadway), San Francisco, CA 94133', 0.663656239687912, 0.6809929513520605, 8.36025735238098, 8.4, 859.0, 0.6463195280237634, 3.9766650806361215, 4.0, 1082.0)
# ('Bars', 'Asian Fusion, Sri Lankan, Wine Bars', '1601 Bar & Kitchen', '1601 Howard St San Francisco, CA 94103', 0.6326722714724587, None, None, None, None, 0.6326722714724587, 3.946233015391415, 4.0, 274.0)
# ('Restaurants', 'Breakfast & Brunch, Filipino, French', '1608 Bistro', '1608 Bush St San Francisco, CA 94109', 0.6327111261195449, None, None, None, None, 0.6327111261195449, 3.946319657505216, 4.0, 275.0)
# ('Bars', 'Bar, Theater', '18th Amendment Speakeasy Dinner', '1630 Powell St, San Francisco, CA 94133', None, None, None, None, None, None, None, None, None)
# ('Bars', 'Sports Bar, Wings Joint', '1920Bar', '1808 Clement St, San Francisco, CA 94121', 0.6191800787904356, None, None, None, None, 0.6191800787904356, 3.916146727612628, 5.0, 4.0)
# ('Restaurants', 'Café, Coffee Shop, Restaurant', '1951 Coffee Company', '2410 Channing Way, Berkeley, CA 94704', 0.6326008426553719, 0.6326008426553719, 8.229418986790499, 8.4, 62.0, None, None, None, None)
# ('Bars', 'Burger Joint, Cocktail Bar, Lounge', '19th Street Station', '19TH St (Webster Street), Oakland, CA 94612', 0.5386255798189235, 0.5386255798189235, 7.975336862109328, 6.3, 21.0, None, None, None, None)
# ('Bars', 'Pubs', '19th Street Station', '339 19th St Oakland, CA 94612', 0.6496997062856553, None, None, None, None, 0.6496997062856553, 3.9842025519966064, 4.5, 54.0)
# ('Bars', 'American Restaurant, New American Restaurant, Wine Bar', '20 Spot', '3565 20th St (at Lexington St), San Francisco, CA 94110', 0.771284408010664, 0.814182610406585, 8.720363943591375, 9.0, 354.0, 0.7283862056147429, 4.159665852804233, 4.5, 260.0)
# ('Bars', 'American Restaurant, Hotel Bar', '2050 Lobby Lounge & Bar', '2050 Gateway Pl (at Brokaw Rd.), San Jose, CA 95110', 0.5316269836990485, 0.5316269836990485, 7.956414667924908, 5.2, 14.0, None, None, None, None)
# ('Restaurants', 'American (Traditional), Sushi Bars', '2050 Lobby Lounge And Bar', '2050 Gateway Pl San Jose, CA 95110', 0.5831811665415448, None, None, None, None, 0.5831811665415448, 3.835872626940577, 3.0, 28.0)
# ('Restaurants', 'Restaurant', '20Twenty Cheese Bar', '1389 Lincoln Ave (Minnesota), San Jose, CA 95125', 0.6134357203659939, 0.5957746591611041, 8.129851561664946, 7.9, 32.0, 0.6310967815708838, 3.942719824934647, 4.0, 236.0)
# ('Restaurants', 'Asian Restaurant, Cantonese Restaurant, Ramen Restaurant', '21 Taste House', '1109 Ocean Ave (Lee), San Francisco, CA 94112', 0.5983370626716835, 0.5609732639153916, 8.035758582523309, 6.3, 14.0, 0.6357008614279754, 3.952986478754492, 4.0, 363.0)
# ('Restaurants', 'American (Traditional)', '211 plaza cafe', 'San Francisco, CA 94105', 0.6149725982548618, None, None, None, None, 0.6149725982548618, 3.90676445201071, 5.0, 1.0)
# ('Bars, Restaurants', 'American Restaurant, Bar, Brewery', '21st Amendment Brewery & Restaurant', '563 2nd St (at De Boom St), San Francisco, CA 94107', 0.6880670713464646, 0.6880670713464646, 8.379383741434618, 8.4, 1823.0, None, None, None, None)
# ('Restaurants', 'Restaurant', '2227 Irving Seafood Market', '2227 Irving St, San Francisco, CA 94122', None, None, None, None, None, None, None, None, None)
# ('Restaurants', 'Latin American', '24th Street BART Tamale/Pupusa Lady', '24TH Street Mission Bart Station San Francisco, CA 94110', 0.6150928968502459, None, None, None, None, 0.6150928968502459, 3.907032706270445, 4.5, 2.0)
# ('Bars', 'American (New), Cocktail Bars, Venues & Event Spaces', '25 Lusk', '25 Lusk St San Francisco, CA 94107', 0.6486233045095253, None, None, None, None, 0.6486233045095253, 3.9818022799010713, 4.0, 1485.0)
# ('Bars', 'Bar', '251 Club', '251 Rhode Island St, San Francisco, CA 94103', None, None, None, None, None, None, None, None, None)
# ('Restaurants', 'Café, Chinese Restaurant', '2546 Cafe', '2546 San Bruno Ave (btwn Felton & Burrows St), San Francisco, CA 94134', 0.5363182023967493, 0.5363182023967493, 7.969098376148532, 5.7, 16.0, None, None, None, None)
# ('Restaurants', 'Deli', '25th & Clement Meat & Deli', '2346 Clement St, San Francisco, CA 94121', None, None, None, None, None, None, None, None, None)
# ('Bars, Restaurants', 'Beer Bar, Restaurant, Sports Bar', '25th St Taproom Bar & Restaurant', '2507 Broadway, Oakland, CA 94612', None, None, None, None, None, None, None, None, None)
# ('Bars', 'Bar, Night Club', '26 Mix', '3024 Mission St (at 26th St), San Francisco, CA 94110', None, None, None, None, None, None, None, None, None)
# ('Bars', 'Cajun / Creole Restaurant, Sports Bar', '2nd Half Bar & Lounge', '4307 Telegraph Ave, Oakland, CA 94609', 0.6167941326622226, None, None, None, None, 0.6167941326622226, 3.910826297973808, 4.0, 28.0)
# ('Bars', 'Lounge', '2nd Half Sports Lounge', '4307 Telegraph Ave, Oakland, CA 94609', None, None, None, None, None, None, None, None, None)
# ('Restaurants', 'Hawaiian, Pop-Up Restaurants', '2x4 bBox', '55 Stevenson St San Francisco, CA 94105', 0.6149725982548618, None, None, None, None, 0.6149725982548618, 3.90676445201071, 5.0, 1.0)
# ('Restaurants', 'Street Food Gathering, Vietnamese Restaurant', '3 Bottled Fish', '3251 20th Ave, San Francisco, CA 94132', None, None, None, None, None, None, None, None, None)
# ('Restaurants', 'Asian Fusion, Food Trucks', '3 Brothers Kitchen', 'San Jose, CA 95148', 0.6250374814785752, None, None, None, None, 0.6250374814785752, 3.929208170408832, 4.0, 125.0)
# ('Restaurants', 'Mexican Restaurant', '3 Hermanos Mexican Grill', '387 S 1st St, San Jose, CA 95113', 0.5710672250961717, None, None, None, None, 0.5710672250961717, 3.8088597064279246, 3.5, 106.0)
# ('Restaurants', 'American (New), Farmers Market', '3 Olives and a Pickle', 'San Francisco, CA', 0.6123846215469653, None, None, None, None, 0.6123846215469653, 3.9009935136737326, 3.0, 1.0)
# ('Restaurants', 'Beer, Wine & Spirits, Convenience Stores, Delis', '3 Ring Liquors', '501 E 18th St Oakland, CA 94606', 0.5956220146237227, None, None, None, None, 0.5956220146237227, 3.8636145177091015, 3.0, 16.0)
# ('Restaurants', 'Burger Joint, Pizzeria, Sandwich Restaurant', '3 Rings Pizza', '501 E 18th St, Oakland, CA 94606', None, None, None, None, None, None, None, None, None)
# ('Restaurants', 'Mexican', '343 Sansome Taqueria', '343 Sansome St Ste 150 San Francisco, CA 94111', 0.612512366184025, None, None, None, None, 0.612512366184025, 3.901278371887913, 3.5, 2.0)
# ('Bars', 'Bar, Restaurant', '360 Sports Bar Lounge', '360 Adeline St, Oakland, CA 94607', None, None, None, None, None, None, None, None, None)
# ('Bars, Restaurants', 'Asian Fusion, Lounges', '386 Lounge', '386 S First St San Jose, CA 95113', 0.6233159556549461, None, None, None, None, 0.6233159556549461, 3.925369333937328, 5.0, 7.0)
# ('Bars', 'Arts and Entertainment, Karaoke Bar', '3910 Geary', '3910 Geary Blvd, San Francisco, CA 94118', None, None, None, None, None, None, None, None, None)
# ('Bars', 'Karaoke, Lounges, Sports Bars', '3910 Lounge', '3910 Geary Blvd San Francisco, CA 94118', 0.618138978705193, None, None, None, None, 0.618138978705193, 3.9138251748814055, 4.0, 41.0)
# ('Restaurants', 'Cafes, Gelato', '3Below Cafe', '288 S 2nd St San Jose, CA 95113', 0.6149725982548618, None, None, None, None, 0.6149725982548618, 3.90676445201071, 5.0, 1.0)
# ('Bars', 'Bar, Movie Theater', '3Below Theaters & Lounge', '288 S 2nd St, San Jose, CA 95113', 0.5830254463542086, 0.5830254463542086, 8.095381351311547, 6.4, 8.0, None, None, None, None)
# ('Bars, Restaurants', 'American Restaurant, Lounge', '3rd & Bourbon', '93 E Santa Clara St, San Jose, CA 95113', 0.6323568599026178, None, None, None, None, 0.6323568599026178, 3.945529678025678, 4.0, 266.0)
# ('Restaurants', 'Mexican Restaurant', '4 Caminos Restaurant', '3800 San Leandro St, Oakland, CA 94601', 0.564664832687481, 0.564664832687481, 8.045739524408532, 6.0, 11.0, None, None, None, None)
# ('Bars', 'Hookah Bar, Lounge', '40 Thieves San Jose', '18 N 1st St, San Jose, CA 95113', None, None, None, None, None, None, None, None, None)
# ('Bars', 'Dive Bars', '400 Club', '400 29th Ave Oakland, CA 94601', 0.6069917751863558, None, None, None, None, 0.6069917751863558, 3.888967986661488, 3.5, 13.0)
# ('Bars, Restaurants', 'Cocktail Bar, Gay Bar, Mexican Restaurant', '440 Castro', '440 Castro St (btwn Market & 18th), San Francisco, CA 94114', 0.4951871834120597, 0.4458401167999988, 7.72447161447066, 7.5, 358.0, 0.5445342500241206, 3.749693732263567, 3.5, 213.0)
# ('Restaurants', 'Barbeque, Burgers, Sandwiches', '4505 Burgers & BBQ - San Francisco', '705 Divisadero St San Francisco, CA 94117', 0.4610073645161839, None, None, None, None, 0.4610073645161839, 3.5634368373404817, 3.5, 1853.0)
# ('Restaurants', 'BBQ Joint, Burger Joint', '4505 Burgers And BBQ', '705 Divisadero St (at Grove St), San Francisco, CA 94117', 0.8755090842750121, 0.8755090842750121, 8.886173118361256, 9.0, 1132.0, None, None, None, None)
# ('Bars', 'Sports Bar', '4Bells Public House', '984 University Ave (9th), Berkeley, CA 94710', 0.63024423335421, None, None, None, None, 0.63024423335421, 3.940818724676398, 4.5, 23.0)
# ('Restaurants', 'Pizzeria', '4th St Pizza Co.', '150 E Santa Clara St (at S. 4th St.), San Jose, CA 95113', 0.4093400657591469, 0.4093400657591469, 7.625785957846629, 6.7, 106.0, None, None, None, None)
# ('Bars', 'Bar, Bowling Alley, Café', '4th Street Bowl', '1441 N 4th St (at E Gish Rd), San Jose, CA 95112', 0.4370354428285933, 0.3591681060213778, 7.490135386144836, 6.2, 95.0, 0.5149027796358089, 3.683618412527051, 3.5, 414.0)
# ('Restaurants', 'Diner', '4th Street Bowl Coffee Shop', '1441 N 4th St (btwn Gish Rd. & Archer St.), San Jose, CA 95112', 0.6134863821230676, 0.6134863821230676, 8.17773897443837, 8.2, 57.0, None, None, None, None)
# ('Restaurants', 'Restaurant', '4th Street Cafe', '1560 N 4th St, San Jose, CA 95112', None, None, None, None, None, None, None, None, None)
# ('Restaurants', 'Restaurant', '4th. Street Shops', 'Delaware Street, Berkeley, CA 94710', None, None, None, None, None, None, None, None, None)
# ('Restaurants', 'Arts and Entertainment, Restaurant', '4zeroEight Tattoo & Body Piercing / Str8 Ink', '809 Lincoln Ave, San Jose, CA 95126', None, None, None, None, None, None, None, None, None)
# ('Restaurants', 'Mexican Restaurant', '5 Spot Chivas Grill', '869 S 1st St, San Jose, CA 95110', 0.6053833013701586, 0.5838264724714785, 8.0975470959092, 6.9, 11.0, 0.6269401302688387, 3.933450893618833, 4.0, 155.0)
# ('Bars', 'Brewery, Concert Hall, Wine Bar', '50 California', '52 California St, San Francisco, CA 94111', None, None, None, None, None, None, None, None, None)
# ('Bars, Restaurants', 'Dive Bar, Restaurant', '500 Club', '500 Guerrero St (at 17th St), San Francisco, CA 94110', 0.5447755062804036, 0.5447755062804036, 7.99196449724226, 7.9, 350.0, None, None, None, None)
# ('Bars, Restaurants', 'Cocktail Bars, Diners, Italian', '54 Mint - Ristorante Italiano', '16 Mint Plz San Francisco, CA 94103', 0.6483419884998911, None, None, None, None, 0.6483419884998911, 3.981174972344612, 4.0, 1424.0)
# ('Bars', 'Bar', '540 Rogues', '540 Clement St (7th Ave), San Francisco, CA 94118', 0.6246789843800916, None, None, None, None, 0.6246789843800916, 3.9284087564716734, 5.0, 8.0)
# ('Bars, Restaurants', 'American Restaurant, Cocktail Bar, Lounge', '55 South', '55 S 1st St (at Post St.), San Jose, CA 95113', 0.5329695384381136, 0.4233477810428491, 7.663658797504509, 7.1, 162.0, 0.642591295833378, 3.968351482599865, 4.0, 707.0)
# ('Bars', 'Lounges', '5A5 Lounge', '244 Jackson St San Francisco, CA 94111', 0.5657577350491909, None, None, None, None, 0.5657577350491909, 3.797020055951771, 3.5, 124.0)
# ('Bars', 'Bars, Steakhouses', '5A5 Steak Lounge', '244 Jackson St San Francisco, CA 94111', 0.6510062963447111, None, None, None, None, 0.6510062963447111, 3.9871161217515088, 4.0, 2240.0)
# ('Restaurants', 'Breakfast & Brunch, Delis, Sandwiches', '5th Avenue Deli & Market', '4 Embarcadero Ctr San Francisco, CA 94111', 0.6591394501385521, None, None, None, None, 0.6591394501385521, 4.00525226991938, 4.5, 71.0)
# ('Bars', 'American (New), Bars, Venues & Event Spaces', '620 Jones', '620 Jones St San Francisco, CA 94102', 0.4727407536232578, None, None, None, None, 0.4727407536232578, 3.5896011628593625, 3.5, 1211.0)
# ('Bars, Restaurants', 'Bar, Restaurant', '7 / Seven Restaurant & Lounge', '754 the Alameda, San Jose, CA 95126', None, None, None, None, None, None, None, None, None)
# ('Bars', 'Karaoke, Lounges', '7 Bamboo Lounge', '162 Jackson St San Jose, CA 95112', 0.6374973451492748, None, None, None, None, 0.6374973451492748, 3.956992464104889, 4.0, 429.0)
# ('Restaurants', 'Coffee Shop, Restaurant', '7 Leaves Cafe', '1743 Berryessa Rd, San Jose, CA 95133', None, None, None, None, None, None, None, None, None)
# ('Restaurants', 'Chinese, Vietnamese', '7 Mission Restaurant', '150 7th St San Francisco, CA 94103', 0.5351657001896706, None, None, None, None, 0.5351657001896706, 3.7288027701322055, 3.5, 264.0)
# ('Restaurants', 'Coffee & Tea, Convenience Stores, Fast Food', '7-Eleven', '527 Sutter St San Francisco, CA 94102', 0.5762863253829135, None, None, None, None, 0.5762863253829135, 3.820497796460724, 3.0, 35.0)
# ('Restaurants', 'Asian Restaurant, Korean Restaurant', '707 Sutter', '707 Sutter St (btwn Jones & Taylor), San Francisco, CA 94109', 0.4500668309289484, 0.2556696040650394, 7.210305157586163, 6.3, 190.0, 0.6444640577928573, 3.972527561061088, 4.0, 867.0)
# ('Restaurants', 'Restaurant', '71 Saint Peter Restaurant', '71 N San Pedro St, San Jose, CA 95110', 0.523657481524595, 0.5376882549899603, 7.972802604934928, 6.7, 28.0, 0.5096267080592297, 3.671853282015245, 3.5, 466.0)
# ('Bars', 'Cocktail Bars, Lounges, Music Venues', '721 Lounge', '721 Sutter St San Francisco, CA 94109', 0.6274928402040447, None, None, None, None, 0.6274928402040447, 3.934683383441704, 4.5, 19.0)
# ('Bars', 'Arts and Entertainment, Hookah Bar, Restaurant', '724Hookah', '724 Geary St (Leavenworth), San Francisco, CA 94109', 0.4743262111506422, 0.3132227996084115, 7.365912471303398, 5.7, 87.0, 0.6354296226928728, 3.952381642547852, 4.0, 354.0)
# ('Bars', 'Arts and Entertainment, Rooftop Bar', '737 Rooftop Bar', '737 2nd St (Brush St), Oakland, CA 94607', None, None, None, None, None, None, None, None, None)
# ('Bars, Restaurants', 'American (New), Wine Bars', '750 Bar & Restaurant', '750 Kearny St Hilton San Francisco Financial District San Francisco, CA 94108', 0.517065351558131, None, None, None, None, 0.517065351558131, 3.688440739240781, 3.0, 108.0)
# ('Restaurants', 'Chinese, Vietnamese', '77 Chinese & Vietnamese Cuisine', '77 Battery St San Francisco, CA 94111', 0.4707757028633572, None, None, None, None, 0.4707757028633572, 3.585219289278424, 3.0, 188.0)
# ('Bars', 'Beer Bar', '788 Beer Club and Cafe', '788 N King Rd, San Jose, CA 95133', 0.6164703835036882, None, None, None, None, 0.6164703835036882, 3.910104368589804, 4.0, 25.0)
# ('Restaurants', 'American Restaurant, Café, Coffee Shop', '7th Street Cafe', '1612 7th St, Oakland, CA 94607', None, None, None, None, None, None, None, None, None)
# ('Bars, Restaurants', 'Asian Restaurant, Lounge, Music Venue', '7th West', '1255 7th St (Union Street), Oakland, CA 94607', 0.6023757305720974, 0.5798494855199892, 8.086794465227843, 7.4, 22.0, 0.6249019756242057, 3.928906005428954, 4.0, 123.0)
# ('Bars', 'Asian Restaurant, Bar, Chinese Restaurant', '80 90 Friendship Restaurant & Bar', '2428 Clement St, San Francisco, CA 94121', None, None, None, None, None, None, None, None, None)
# ('Bars', 'Cocktail Bar, Lounge, Restaurant', '800 Larkin', "800 Larkin St (at O'Farrell St.), San Francisco, CA 94109", 0.5578779820930314, 0.4922755064779086, 7.850019573727715, 6.2, 35.0, 0.6234804577081543, 3.925736157642685, 4.0, 103.0)
# ('Restaurants', 'Hawaiian Restaurant', '808 Poke Shack', '428 11th St, San Francisco, CA 94103', None, None, None, None, None, None, None, None, None)
# ('Bars', 'Cocktail Bar, Restaurant', '83 Proof', '83 1st St (btwn Market & Mission), San Francisco, CA 94105', 0.507262420388991, 0.3713516428461648, 7.523076171082684, 7.2, 361.0, 0.6431731979318173, 3.9696490681299066, 4.0, 752.0)
# ('Restaurants', 'Pizzeria', '8Mile Detroit Style Pizza North Oakland / Berkeley', '5333 Adeline St, Oakland, CA 94608', 0.6145320286440189, None, None, None, None, 0.6145320286440189, 3.905782024290413, 4.0, 8.0)
# ('Restaurants', 'Chicken Wings, Pizza, Salad', '8MilePi Detroit Style Pizza', '949 Ruff Dr San Jose, CA 95110', 0.5902770977973653, None, None, None, None, 0.5902770977973653, 3.851695868933374, 3.5, 51.0)
# ('Restaurants', 'Chicken Wings, Pizza, Salad', '8MilePi Detroit Style Pizza', '60 Morris St San Francisco, CA 94107', 0.6045928494105436, None, None, None, None, 0.6045928494105436, 3.883618613660967, 3.5, 18.0)
# ('Restaurants', 'Chicken Wings, Pizza', '8MilePi Detroit Style Pizza', '2353 E 12th St Oakland, CA 94601', 0.5696405469687882, None, None, None, None, 0.5696405469687882, 3.8056783518683095, 3.0, 42.0)
# ('Restaurants', 'Food Stands, Latin American, Salad', '9 Julio Empanada Kitchen', '5239 Claremont Ave Ste A Oakland, CA 94618', 0.6491862971004584, None, None, None, None, 0.6491862971004584, 3.983057699054009, 5.0, 27.0)
# ('Restaurants', 'American Restaurant, Burger Joint', '900 Grayson', '900 Grayson St (at 7th St.), Berkeley, CA 94710', 0.6928557648885345, 0.7347119451037986, 8.505498085486781, 8.7, 310.0, 0.6509995846732703, 3.987101155371825, 4.0, 2237.0)
# ('Restaurants', 'Cafes', '901 Columbus Cafe', '901 Columbus Ave San Francisco, CA 94133', 0.6356112173726789, None, None, None, None, 0.6356112173726789, 3.9527865811612046, 4.0, 360.0)
# ('Funeral Homes', 'Cremation Services', 'A Atlantis Burial Cremation & Scattering Services', 'San Francisco, CA 94102', 0.6097966448390689, None, None, None, None, 0.6097966448390689, 3.895222575336756, 1.0, 1.0)
# ('Restaurants', 'Asian Fusion, Food Stands', 'A Humble Plate', 'San Francisco, CA 94102', 0.6136786099009136, None, None, None, None, 0.6136786099009136, 3.9038789828422216, 4.0, 1.0)
# ('Bars, Restaurants', 'Bar, Night Club, Restaurant', "A J'S Bar", '393 Lincoln Ave, San Jose, CA 95126', None, None, None, None, None, None, None, None, None)
# ('Restaurants', 'Delis, Salad, Sandwiches', 'A K Meats', '2346 Clement St San Francisco, CA 94121', 0.7406690027286376, None, None, None, None, 0.7406690027286376, 4.187055305164298, 4.5, 313.0)
# ('Restaurants', 'Mediterranean, Turkish', 'A La Turca', '869 Geary St San Francisco, CA 94109', 0.6446442680114478, None, None, None, None, 0.6446442680114478, 3.97292941245952, 4.0, 885.0)
# ('Restaurants', 'Italian Restaurant', 'A Mano', '450 Hayes St (Octavia Street), San Francisco, CA 94102', 0.7143835931866886, 0.780326187892667, 8.628825899357214, 8.8, 482.0, 0.6484409984807105, 3.981395755048069, 4.0, 1445.0)
# ('Restaurants', 'Taiwanese Restaurant', 'A Sack Of Potatoes', '929 Story Rd, San Jose, CA 95122', None, None, None, None, None, None, None, None, None)
# ('Restaurants', 'Seafood Restaurant', 'A Tarantino & Sons Poultry & Seafood', '2275 Jennings St, San Francisco, CA 94124', 0.6163831621833562, None, None, None, None, 0.6163831621833562, 3.90990987346171, 5.0, 2.0)
# ('Restaurants', 'Restaurant, Street Food Gathering', 'A Taste Of Chicago', '345 Williams Ave, San Francisco, CA 94124', 0.6112221008509148, None, None, None, None, 0.6112221008509148, 3.898401204696648, 3.0, 2.0)
# ('Restaurants', 'Italian', 'A Taste Of North Beach', '24 Willie Mays Plz San Francisco, CA 94107', 0.6140485460134877, None, None, None, None, 0.6140485460134877, 3.904703904677017, 4.0, 4.0)
# ('Restaurants', 'American Restaurant, Fast Food Restaurant', 'A&W Restaurant', '2996 Telegraph Ave, Berkeley, CA 94705', None, None, None, None, None, None, None, None, None)
# ('Restaurants', 'Restaurant', 'A+ Burger', '6228 Telegraph Ave (at 63rd St), Oakland, CA 94609', 0.6728241956175159, 0.5480110924004139, 8.000712592976686, 6.2, 17.0, 0.797637298834618, 4.314089108438941, 4.5, 763.0)
# ('Restaurants', 'Restaurants', 'A1 Ocean Cafe', '380 Bush St San Francisco, CA 94104', 0.612512366184025, None, None, None, None, 0.612512366184025, 3.901278371887913, 3.5, 2.0)
# ('Restaurants', 'Italian, Pizza', 'A16', '5356 College Ave Oakland, CA 94618', 0.4945118854205703, None, None, None, None, 0.4945118854205703, 3.638148686005588, 3.5, 664.0)
# ('Restaurants', 'Italian Restaurant, Pizzeria', 'A16', '2355 Chestnut St (btwn Divisadero & Scott St), San Francisco, CA 94123', 0.5381497986567018, 0.618887031506292, 8.192340779514838, 8.2, 509.0, 0.4574125658071116, 3.555420783092156, 3.5, 2171.0)
# ('Restaurants', 'Italian Restaurant, Pizzeria', 'A16 Rockridge', '5356 College Ave (btwn Bryant & Manila), Oakland, CA 94618', 0.6160631409442653, 0.6160631409442653, 8.1847057903463, 8.2, 165.0, None, None, None, None)
# ('Bars', 'Arts and Entertainment, Bar', 'AAANCNU Club', '3400 Ettie St, Emeryville, CA 94608', None, None, None, None, None, None, None, None, None)
# ('Restaurants', 'Fried Chicken Joint', 'ABC Chicken', '2891 San Bruno Ave, San Francisco, CA 94134', 0.617112723349738, None, None, None, None, 0.617112723349738, 3.911536724465197, 4.0, 31.0)
# ('Bars', 'Cocktail Bars, Mexican', 'ABVE The Basics', '1 E San Fernando St San Jose, CA 95113', 0.7212637173220363, None, None, None, None, 0.7212637173220363, 4.143783391181747, 4.5, 233.0)
# ('Bars', 'American Restaurant, Bar, Tapas Restaurant', 'AC Lounge', '350 W Santa Clara St, San Jose, CA 95113', 0.6043850729079465, None, None, None, None, 0.6043850729079465, 3.883155292109153, 3.0, 8.0)
# ('Bars', 'Hotel Bar', 'AC Lounge at AC Hotel San Jose Downtown', 'San Jose, CA 95113', 0.5169225840677254, 0.5169225840677254, 7.916658193851621, 6.9, 45.0, None, None, None, None)
# ('Restaurants', 'American (Traditional)', 'AFICI', '680 Folsom St San Francisco, CA 94107', 0.6355716618943319, None, None, None, None, 0.6355716618943319, 3.9526983762613175, 4.5, 31.0)
# ('Restaurants', 'Coffee & Tea, Sandwiches', 'AIDS Health Alliance Cafe', '200 McAllister St San Francisco, CA 94102', 0.6123846215469653, None, None, None, None, 0.6123846215469653, 3.9009935136737326, 3.0, 1.0)
# ('Restaurants', 'American (New)', "AJ's Bar and Grill", '1471 N 4th St Radisson San Jose, CA 95112', 0.6045762732010244, None, None, None, None, 0.6045762732010244, 3.883581650313227, 2.5, 5.0)
# ('Bars', 'Cocktail Bars, Lounges, Restaurants', 'AJI Bar & Robata', '170 S Market St San Jose, CA 95113', 0.6156941907664831, None, None, None, None, 0.6156941907664831, 3.908373533683001, 4.0, 18.0)
# ('Restaurants', 'Restaurant', 'AK Subs', '397 8th St, San Francisco, CA 94103', 0.7133556564494059, 0.6595847293716148, 8.302375667751862, 8.5, 120.0, 0.7671265835271971, 4.246053157373789, 4.5, 466.0)
# ('Bars', 'American Restaurant, Cocktail Bar, Steakhouse', "ALX by Alexander's Steakhouse", '680 Folsom St, San Francisco, CA 94107', None, None, None, None, None, None, None, None, None)
# ('Restaurants', 'American (Traditional)', 'AT&T Park Bratwurst Cart', '24 Willie Mays Plz Behind Sections 134 and 107 San Francisco, CA 94107', 0.6173685103173261, None, None, None, None, 0.6173685103173261, 3.912107104721267, 4.5, 5.0)
# ('Restaurants', 'Asian Restaurant, Korean Restaurant', 'AYI Super Korean food & soju house', '1650 Balboa St, San Francisco, CA 94121', None, None, None, None, None, None, None, None, None)
# ('Restaurants', 'Indian Restaurant', 'Aaha Indian Cuisine', '3316 17th St (Mission), San Francisco, CA 94110', 0.6712259314550817, None, None, None, None, 0.6712259314550817, 4.032203956994421, 4.5, 95.0)
# ('Restaurants', 'Filipino Restaurant', 'Abac', '2700 Jones St, San Francisco, CA 94133', 0.627933567689203, 0.6207786558353328, 8.197455188499868, 8.3, 47.0, 0.6350884795430732, 3.951620926241724, 4.0, 343.0)
# ('Bars', 'Bar, Deli', "Abba's Hummus", '3417 Lakeshore Ave, Oakland, CA 94610', 0.6443695085972793, None, None, None, None, 0.6443695085972793, 3.972316725478284, 4.5, 45.0)
# ('Bars, Restaurants', 'Restaurant, Sports Bar', 'Abbey Tavern', '4100 Geary Blvd (at 5th Avenue), San Francisco, CA 94118', 0.3979574540360495, 0.3979574540360495, 7.595010644389313, 6.0, 65.0, None, None, None, None)
# ('Restaurants', 'Cafes, Sandwiches', "Abe's Cafe", '1842 Euclid Ave Berkeley, CA 94709', 0.6767884519944983, None, None, None, None, 0.6767884519944983, 4.044607841053035, 4.5, 107.0)
# ('Restaurants', 'Pizza', 'Abes Pizza', '940 Market St San Francisco, CA 94102', 0.6195825250421294, None, None, None, None, 0.6195825250421294, 3.91704414392066, 4.0, 56.0)
# ('Restaurants', 'African Restaurant, Ethiopian Restaurant', 'Abesha Ethiopian Cuisine', '4929 Shattuck Ave, Oakland, CA 94609', 0.608379001376854, 0.5888376132513174, 8.111095781573786, 7.6, 21.0, 0.6279203895023906, 3.9356367771215015, 4.0, 172.0)
# ('Bars', 'Cocktail Bar', "Abhay's Roof Party", '1815 Powell St (Filbert), San Francisco, CA 94133', None, None, None, None, None, None, None, None, None)
# ('Restaurants', 'American (New), Seafood, Spanish', 'Abrazo', '2000 Hyde St San Francisco, CA 94109', 0.696371533156713, None, None, None, None, 0.696371533156713, 4.088276222414558, 4.5, 155.0)
# ('Bars', 'Beer Bar, Cocktail Bars, French', 'Absinthe Brasserie & Bar', '398 Hayes St San Francisco, CA 94102', 0.6527999258542825, None, None, None, None, 0.6527999258542825, 3.991115742485164, 4.0, 3404.0)
# ('Restaurants', 'American Restaurant, Tapas Restaurant', 'Abstract Table', '2085 Vine St, Berkeley, CA 94709', 0.6201301917182571, None, None, None, None, 0.6201301917182571, 3.9182653877624247, 4.0, 62.0)
# ('Restaurants', 'Arabic, Falafel, Halal', 'Abu Salim Middle Eastern Grill', '1599 Haight St San Francisco, CA 94117', 0.7266013346032104, None, None, None, None, 0.7266013346032104, 4.155685762676071, 4.5, 253.0)
# ('Restaurants', 'BBQ Joint, Japanese Restaurant', 'Aburaya Go', '380 15th St, Oakland, CA 94612', None, None, None, None, None, None, None, None, None)
# ('Restaurants', 'Japanese Restaurant', 'Aburaya Japanese Fried Chicken', '362 17th St (btwn Franklin and Webster St), Oakland, CA 94612', 0.6902895013665733, 0.7359052109969773, 8.508724333802533, 8.8, 209.0, 0.6446737917361693, 3.972995247516816, 4.0, 888.0)
# ('Bars, Restaurants', 'American Restaurant, Cocktail Bar, Gastropub', 'Abv', '3174 16th St (btwn Guerrero & Albion St), San Francisco, CA 94103', 0.7553357893044268, 0.8687288928619534, 8.867841427786757, 9.0, 950.0, 0.6419426857469003, 3.966905144693352, 4.0, 661.0)
# ('Restaurants', 'Bakery, Ethiopian Restaurant', 'Abyssinia Market', '2525 Telegraph Ave (40th And Telegraph), Oakland, CA 94612', 0.6146511948050511, None, None, None, None, 0.6146511948050511, 3.906047753330815, 4.0, 9.0)
# ('Restaurants', 'Bakery, Coffee Shop, Restaurant', 'Academic Coffee', '499 S 2nd St (E. William St.), San Jose, CA 95113', 0.666838182914884, 0.666838182914884, 8.321986923224033, 8.8, 57.0, None, None, None, None)
# ('Bars', 'American Restaurant, Pizzeria, Wine Bar', 'Academy Bar & Kitchen', '1800 Fillmore St (Sutter Street), San Francisco, CA 94115', 0.4851446126352217, 0.4110083931957273, 7.630296636156601, 5.0, 37.0, 0.5592808320747161, 3.7825771872944793, 3.5, 148.0)
# ('Restaurants', 'American (Traditional), Coffee & Tea, Mediterranean', 'Academy Caf', '55 Music Concourse Dr The California Academy Of Sciences San Francisco, CA 94118', 0.4568052493893055, None, None, None, None, 0.4568052493893055, 3.5540665260822304, 3.0, 218.0)
# ('Restaurants', 'Restaurant', 'Acai R', '1130 Ocean Ave, San Francisco, CA 94112', None, None, None, None, None, None, None, None, None)
# ('Restaurants', 'Restaurants', 'Ace', '1611 Telegraph Ave Oakland, CA 94612', 0.6123846215469653, None, None, None, None, 0.6123846215469653, 3.9009935136737326, 3.0, 1.0)
# ('Restaurants', 'Japanese, Sushi Bars', 'Ace Wasabi  Rock-N-Roll Sushi', '3339 Steiner St San Francisco, CA 94123', 0.646025614945772, None, None, None, None, 0.646025614945772, 3.976009682832756, 4.0, 1043.0)
# ('Restaurants', 'Sushi Restaurant', 'Ace Wasabis', '3339 Steiner St (btw Lombard & Chestnut), San Francisco, CA 94123', 0.5850140760787279, 0.5850140760787279, 8.100758035029786, 8.0, 125.0, None, None, None, None)
# ('Bars, Restaurants', 'BBQ Joint, Sports Bar', "Ace's", '998 Sutter St (at Hyde St.), San Francisco, CA 94109', 0.5796468953571166, 0.5253322444895044, 7.939395500705782, 7.7, 174.0, 0.6339615462247288, 3.949107973682991, 4.0, 309.0)
# ('Restaurants', 'BBQ Joint', 'Aceking BBQ', '1820 Clement St, San Francisco, CA 94121', 0.6248337879784756, None, None, None, None, 0.6248337879784756, 3.9287539535586062, 4.0, 122.0)
# ('Bars', 'BBQ Joint, Cocktail Bar, Dive Bar', 'Acme Bar', '2115 San Pablo Ave (at Addison St), Berkeley, CA 94702', 0.5059833610779502, 0.5059833610779502, 7.887081676205264, 7.3, 87.0, None, None, None, None)
# ('Bars, Restaurants', 'Cocktail Bars, Sandwiches, Venues & Event Spaces', 'Acme Bar & Company', '2115 San Pablo Ave Berkeley, CA 94702', 0.6351199423047861, None, None, None, None, 0.6351199423047861, 3.951691085164408, 4.0, 344.0)
# ('Restaurants', 'Bakery, Restaurant', 'Acme Bread', '2730 9th St, Berkeley, CA 94710', None, None, None, None, None, None, None, None, None)
# ('Restaurants', 'Bakery, Mexican Restaurant', 'Acme Bread Company', '1601 San Pablo Ave (at Cedar St), Berkeley, CA 94702', 0.7461074219348733, 0.7461074219348733, 8.536308182501712, 9.0, 142.0, None, None, None, None)
# ('Restaurants', 'Mexican Restaurant', 'Acopio', '399 S 24th St (E William), San Jose, CA 95116', 0.6731134711091201, None, None, None, None, 0.6731134711091201, 4.036412988288566, 4.5, 99.0)
# ('Bars', 'Bar, Fast Food Restaurant, Italian Restaurant', 'Acoustic Bistro', '3277 Sacramento St, San Francisco, CA 94115', None, None, None, None, None, None, None, None, None)
# ('Restaurants', 'Italian Restaurant', 'Acquerello', '1722 Sacramento St (btwn Polk & Van Ness Ave), San Francisco, CA 94109', 0.7107555749142896, 0.5995370152118623, 8.140023892024345, 8.1, 138.0, 0.821974134616717, 4.36835790389877, 4.5, 1220.0)
# ('Bars, Restaurants', 'Italian, Pizza, Wine Bars', 'Acquolina', '1600 Stockton St San Francisco, CA 94133', 0.6421031230409483, None, None, None, None, 0.6421031230409483, 3.967262904378003, 4.0, 672.0)
# ('Restaurants', 'Restaurant', 'Acre Catering', '3601 Lyon St, San Francisco, CA 94123', None, None, None, None, None, None, None, None, None)
# ('Bars, Restaurants', 'American (New), Bars, Mediterranean', 'Acre Kitchen & Bar', '5655 College Ave Rockridge Market Hall Oakland, CA 94618', 0.6156941907664831, None, None, None, None, 0.6156941907664831, 3.908373533683001, 4.0, 18.0)
# ('Bars', 'Beer Garden', 'Action House', '3030 Acton St (One Block South Of Ashby), Berkeley, CA 94702', 0.5939393460708973, 0.5939393460708973, 8.124889402099333, 7.3, 10.0, None, None, None, None)
# ('Restaurants', 'Café, Sandwich Restaurant', "Ada's Cafe", '3075 Adeline St, Berkeley, CA 94703', 0.6164703835036882, None, None, None, None, 0.6164703835036882, 3.910104368589804, 4.0, 25.0)
# ('Restaurants', 'Asian Fusion, Burgers, Food Trucks', "Adam's Grub Truck", 'San Francisco, CA 94158', 0.6363357552028486, None, None, None, None, 0.6363357552028486, 3.9544022306096553, 4.0, 385.0)
# ('Restaurants', 'Barbeque', "Adam's Smoked Meats", '2351 Taylor St San Francisco, CA 94133', 0.6295619991756423, None, None, None, None, 0.6295619991756423, 3.9392974082890135, 4.5, 22.0)
# ('Restaurants', 'African Restaurant, Ethiopian Restaurant, Fast Food Restaurant', 'Addis Ethiopian Restaurant', '6100 Telegraph Ave, Oakland, CA 94609', 0.6447476785583919, 0.6475085690153752, 8.269725197950635, 8.6, 54.0, 0.6419867881014086, 3.967003488688337, 4.0, 664.0)
# ('Restaurants', 'Desserts, Soul Food', 'Adeline Collective', '3801 San Pablo Ave Emeryville, CA 94608', 0.6097966448390689, None, None, None, None, 0.6097966448390689, 3.895222575336756, 1.0, 1.0)
# ('Restaurants', 'Empanadas, Pizza', 'Adeline Food Hall', '5333 Adeline St Oakland, CA 94608', 0.5989846419941823, None, None, None, None, 0.5989846419941823, 3.8711128522752296, 2.0, 6.0)
# ('Restaurants', 'Indian', 'Aditi Indian Cuisine', '1101 Valencia St San Francisco, CA 94110', 0.7087595211077689, None, None, None, None, 0.7087595211077689, 4.115900240191314, 4.5, 191.0)
# ('Restaurants', 'Eritrean, Ethiopian', 'Admas', '1910 Park Blvd Oakland, CA 94606', 0.6173685103173261, None, None, None, None, 0.6173685103173261, 3.912107104721267, 4.5, 5.0)
# ('Restaurants', 'Japanese, Specialty Food', 'Aedan Koji Kitchen', '613 York St San Francisco, CA 94110', 0.6340084904746195, None, None, None, None, 0.6340084904746195, 3.949212654830456, 5.0, 15.0)
# ('Bars, Restaurants', 'American Restaurant, BBQ Joint, Hotel Bar', 'Affinity Restaurant & Bar', '300 Almaden Blvd, San Jose, CA 95110', 0.5235665888331107, 0.4909553208331707, 7.846450170850147, 5.9, 30.0, 0.5561778568330505, 3.7756578519209496, 3.0, 57.0)
# ('Restaurants', 'Afghan Restaurant', 'Afghan Burrito', '2309 San Pablo Ave, Berkeley, CA 94702', 0.7658029360445874, None, None, None, None, 0.7658029360445874, 4.243101551210284, 5.0, 155.0)
# ('Restaurants', 'Afghan Restaurant, Mexican Restaurant', 'Afghan Burrito', '3015 Adeline St, Oakland, CA 94608', None, None, None, None, None, None, None, None, None)
# ('Restaurants', 'Restaurant', 'After Hours Formalwear', '3251 20th Ave, San Francisco, CA 94132', None, None, None, None, None, None, None, None, None)
# ('Bars', 'Bar', 'Afterwork Bar', '409 Gough St (Hayes), San Francisco, CA 94102', 0.6016112741505809, 0.5849838568196719, 8.10067633083109, 7.2, 14.0, 0.6182386914814899, 3.9140475247509623, 4.0, 42.0)
# ('Restaurants', 'Latin American Restaurant, Mexican Restaurant', 'Agave Uptown', '2135 Franklin St (at 22nd St), Oakland, CA 94612', 0.5640087235988507, 0.4869822386660994, 7.835708097584556, 7.1, 82.0, 0.6410352085316019, 3.964881558068434, 4.0, 603.0)
# ('Restaurants', 'Italian Restaurant', 'Agrodolce', '1730 Shattuck Ave, Berkeley, CA 94709', 0.5773591133790299, 0.5773591133790299, 8.080061214096395, 7.6, 34.0, None, None, None, None)
# ('Restaurants', 'Italian', 'Agrodolce Osteria', '1730 Shattuck Ave Berkeley, CA 94709', 0.495446256036016, None, None, None, None, 0.495446256036016, 3.6402322423178095, 3.5, 649.0)
# ('Restaurants', 'Seafood Restaurant, Taco Restaurant', 'Aguachiles El Tamarindo', '3053 International Blvd, Oakland, CA 94601', 0.635671064538811, None, None, None, None, 0.635671064538811, 3.9529200345668474, 4.0, 362.0)
# ('Restaurants', 'Ethiopian Restaurant', 'Ahadu Ethiopian Cuisine', '6430 Telegraph Ave (65th Street), Oakland, CA 94609', None, None, None, None, None, None, None, None, None)
# ('Restaurants', 'American Restaurant, Burger Joint, Fast Food Restaurant', "Ahn's Quarter Pound Burger", '439 Grand Ave (at Bellevue Ave), Oakland, CA 94610', 0.6053142347590272, 0.5733070146652562, 8.069105502778989, 7.6, 39.0, 0.6373214548527981, 3.956600245715928, 4.0, 422.0)
# ('Restaurants', 'Halal, Middle Eastern, Moroccan', 'Aicha Moroccan Cuisine', '1303 Polk St San Francisco, CA 94109', 0.6406438538728534, None, None, None, None, 0.6406438538728534, 3.964008874942409, 4.0, 580.0)
# ('Bars', 'Coffee & Tea, Wine Bars', "Ain't Normal Cafe", '5701 College Ave Oakland, CA 94618', 0.6702692499030126, None, None, None, None, 0.6702692499030126, 4.030070649446378, 4.5, 93.0)
# ('Restaurants', 'Asian Restaurant, Hawaiian Restaurant', 'Aina', '900 22nd St, San Francisco, CA 94107', None, None, None, None, None, None, None, None, None)
# ('Bars', 'Cocktail Bar, Lounge, Restaurant', 'Air Bar & Lounge', '492 9th St, Oakland, CA 94607', None, None, None, None, None, None, None, None, None)
# ('Bars, Restaurants', 'Airport Lounges, Parking, Sushi Bars', 'Airport Parking at Doubletree San Jose', '2050 Gateway Pl San Jose, CA 95110', 0.6028113971361395, None, None, None, None, 0.6028113971361395, 3.879646146986717, 2.5, 6.0)
# ('Restaurants', 'Ramen', 'Ajisen Ramen', '865 Market St Ste C-12 865 San Francisco, CA 94103', 0.476994246061249, None, None, None, None, 0.476994246061249, 3.5990860405638445, 3.5, 1062.0)
# ('Restaurants', 'Japanese', 'Akari Japanese Bistro', '1155 Folsom St San Francisco, CA 94103', 0.6246789843800916, None, None, None, None, 0.6246789843800916, 3.9284087564716734, 5.0, 8.0)
# ('Restaurants', 'Japanese, Soup, Taiwanese', 'Aki Japanese Restaurant', '2505 Hearst Ave Ste C Berkeley, CA 94709', 0.5674817505580935, None, None, None, None, 0.5674817505580935, 3.8008644441811983, 3.5, 118.0)
# ('Bars, Restaurants', 'Creperie, Karaoke Bar, Sushi Restaurant', 'Akiba', '3141 Clement St (33rd Ave.), San Francisco, CA 94121', 0.5768592383345847, 0.5386255798189235, 7.975336862109328, 6.3, 21.0, 0.6150928968502459, 3.907032706270445, 4.5, 2.0)
# ('Restaurants', 'Japanese, Sushi Bars', "Akiko's Restaurant", '430 Folsom St San Francisco, CA 94105', 0.6503437201911936, None, None, None, None, 0.6503437201911936, 3.985638640863124, 4.0, 1974.0)
# ('Restaurants', 'Sushi Bars', "Akiko's Sushi Bar", '542 Mason St Ste A San Francisco, CA 94102', 0.5035877796718197, None, None, None, None, 0.5035877796718197, 3.658387054425626, 3.5, 535.0)
# ('Restaurants', 'Asian Restaurant, Sushi Restaurant', 'Akira Japanese Restaurant', '1634 Bush St (Franklin), San Francisco, CA 94109', 0.6169840808389391, 0.5953013061602387, 8.128571751079118, 8.0, 59.0, 0.6386668555176396, 3.959600359376781, 4.0, 479.0)
# ('Restaurants', 'Mexican', 'Al Carajo', '3224 1/2 22nd St San Francisco, CA 94110', 0.6735203288525594, None, None, None, None, 0.6735203288525594, 4.037320241797512, 5.0, 48.0)
# ('Restaurants', 'Middle Eastern', 'Al Fanous', '3170 16th St San Francisco, CA 94103', 0.6119960960074652, None, None, None, None, 0.6119960960074652, 3.9001271392106416, 3.5, 3.0)
# ('Restaurants', 'Egyptian, Halal', 'Al Masri', '4031 Balboa St San Francisco, CA 94121', 0.5372261970719064, None, None, None, None, 0.5372261970719064, 3.7333974793560696, 3.5, 252.0)
# ('Restaurants', 'American Restaurant', "Al's Good Food Cafe", '3286 Mission St, San Francisco, CA 94110', 0.5251679204797736, 0.5251679204797736, 7.9389512157709134, 6.2, 24.0, None, None, None, None)
# ('Restaurants', 'American Restaurant, New American Restaurant, Seafood Restaurant', "Al's Place", '1499 Valencia St (at 26th St), San Francisco, CA 94110', 0.5374302517332846, 0.5374302517332846, 7.972105038217346, 7.9, 496.0, None, None, None, None)
# ('Restaurants', 'American (Traditional), Breakfast & Brunch, Burgers', "Al's Super Cafe", '3286 Mission St San Francisco, CA 94110', 0.5527081808888226, None, None, None, None, 0.5527081808888226, 3.767920809364756, 3.5, 175.0)
# ('Restaurants', 'Pakistani Restaurant', 'Al-Maida', '5650 Market St, Oakland, CA 94608', None, None, None, None, None, None, None, None, None)
# ('Restaurants', 'Pakistani', 'Al-Maida Pakistani Restaurant', '5650 Market St Oakland, CA 94608', 0.6702692499030126, None, None, None, None, 0.6702692499030126, 4.030070649446378, 4.5, 93.0)
# ('Restaurants', 'Egyptian Restaurant, Mediterranean Restaurant, Middle Eastern Restaurant', 'Al-Masri Egyptian Restaurant', '4031 Balboa St, San Francisco, CA 94121', 0.575159886167205, 0.575159886167205, 8.074115135247862, 5.9, 8.0, None, None, None, None)
# ('Bars', 'Cocktail Bars, Seafood', 'Alamar Kitchen & Bar', '100 Grand Ave Ste 111 Oakland, CA 94612', 0.6403055831275616, None, None, None, None, 0.6403055831275616, 3.963254563821167, 4.0, 561.0)
# ('Bars', 'Lounge', 'Alameda County Bar Association', '70 Washington St, Oakland, CA 94607', None, None, None, None, None, None, None, None, None)
# ('Bars', 'Bars, Cinema, Dinner Theater', 'Alamo Drafthouse Cinema New Mission', '2550 Mission St San Francisco, CA 94110', 0.4815925539867471, None, None, None, None, 0.4815925539867471, 3.609339823533187, 3.5, 930.0)
# ('Restaurants', 'American Restaurant, Coffee Shop, Sandwich Restaurant', 'Alamo Square Cafe', '711 Fillmore St (at Hayes St.), San Francisco, CA 94117', 0.526326613382528, 0.4241321523253079, 7.665779512211452, 6.5, 78.0, 0.6285210744397481, 3.9369762465699183, 4.0, 183.0)
# ('Bars', 'Speakeasy', 'Alamo Square Hideout', '995 Steiner St (Mcallister), San Francisco, CA 94117', None, None, None, None, None, None, None, None, None)
# ('Restaurants', 'Food Stands, Shopping', 'Alamo Square Neighborhood Association Flea Market', '700 Scott St San Francisco, CA 94115', 0.6114827796250136, None, None, None, None, 0.6114827796250136, 3.8989824932092114, 3.5, 4.0)
# ('Restaurants', 'Seafood', 'Alamo Square Seafood Grill', '803 Fillmore St San Francisco, CA 94117', 0.6427380857820542, None, None, None, None, 0.6427380857820542, 3.9686788100212103, 4.0, 718.0)
# ('Restaurants', 'Fast Food Restaurant, Ice Cream Parlor', "Alawdi's Mini Mart and Kitchen", '3841 West St, Oakland, CA 94608', None, None, None, None, None, None, None, None, None)
# ('Restaurants', 'Convenience Stores, Fast Food, Ice Cream & Frozen Yogurt', "Alawdi's Mini Mart and Kitchen", '3841 W St Oakland, CA 94608', 0.6136786099009136, None, None, None, None, 0.6136786099009136, 3.9038789828422216, 4.0, 1.0)
# ('Restaurants', 'Deli', 'Albert & Eve Organics Co.', '2050 Galvez Ave, San Francisco, CA 94124', None, None, None, None, None, None, None, None, None)
# ('Funeral Homes', 'Funeral Services & Cemeteries', 'Albert Brown Mortuary', '2850 Telegraph Avenue Oakland, CA 94609', 0.5958511647720861, None, None, None, None, 0.5958511647720861, 3.864125500428567, 2.5, 10.0)
# ('Funeral Homes', 'Funeral Home', 'Albert Brown Mortuary', '3476 Piedmont Ave, Oakland, CA 94611', None, None, None, None, None, None, None, None, None)
# ('Restaurants', 'Persian/Iranian, Salad, Sandwiches', 'Alborz', '2175 Allston Way Berkeley, CA 94704', 0.6189225288029014, None, None, None, None, 0.6189225288029014, 3.915572415992197, 4.0, 49.0)
# ('Bars, Restaurants', 'Cocktail Bar, Lounge, Restaurant', 'Alchemist Bar & Lounge', '679 3rd St (Townsend St), San Francisco, CA 94107', 0.5091806368485579, 0.3775108391775602, 7.539728869281921, 7.3, 474.0, 0.6408504345195555, 3.9644695298509687, 4.0, 592.0)
# ('Bars', 'American (Traditional), Beer Gardens, Cocktail Bars', 'Alchemist Cocktail Garden', '685 3rd St San Francisco, CA 94107', 0.6155808594122126, None, None, None, None, 0.6155808594122126, 3.90812081569866, 4.0, 17.0)
# ('Bars', 'Hotel Bar', 'Ale Industries', '3096 E 10th St, Oakland, CA 94601', 0.5846295646524755, 0.5846295646524755, 8.099718426549877, 7.9, 64.0, None, None, None, None)
# ('Bars', 'Spanish, Tapas/Small Plates, Wine Bars', 'Alegrias', '2018 Lombard St San Francisco, CA 94123', 0.6446442680114478, None, None, None, None, 0.6446442680114478, 3.97292941245952, 4.0, 885.0)
# ('Restaurants', 'Diner, Latin American Restaurant, Tapas Restaurant', 'Alegrias Food From Spain', '2018 Lombard St (at Webster), San Francisco, CA 94123', 0.6031209066043057, 0.6031209066043057, 8.149713705195747, 8.1, 76.0, None, None, None, None)
# ('Restaurants', 'Coffee & Tea, Eritrean, Ethiopian', "Alem's Coffee", '5353 Claremont Ave Oakland, CA 94618', 0.6886873349653418, None, None, None, None, 0.6886873349653418, 4.071141201919123, 4.5, 135.0)
# ('Restaurants', 'Steakhouse', "Alexander's Steakhouse", '448 Brannan St (btwn 3rd & 4th St), San Francisco, CA 94107', 0.6342926978111817, 0.6184776949066468, 8.191234050894897, 8.2, 422.0, 0.6501077007157166, 3.985112340207037, 4.0, 1892.0)
# ('Restaurants', 'Food Trucks, Tacos', 'Alfaro Catering', '332 Valencia St San Francisco, CA 94103', 0.6349181453227505, None, None, None, None, 0.6349181453227505, 3.951241097366464, 4.5, 30.0)
# ('Restaurants', 'Seafood', "Alfonso Scunatelli's Famous Fishwich", 'Pier 43 1/2 San Francisco, CA 94133', 0.5893000503474958, None, None, None, None, 0.5893000503474958, 3.849517147398403, 3.0, 22.0)
# ('Restaurants', 'Indian, Pakistani, Pizza', 'Alhamra', '3083 16th St San Francisco, CA 94103', 0.503186743433503, None, None, None, None, 0.503186743433503, 3.657492782311369, 3.5, 540.0)
# ('Restaurants', 'Mediterranean', "Ali's Gyro Lab", '1338 Polk St San Francisco, CA 94109', 0.5989846419941823, None, None, None, None, 0.5989846419941823, 3.8711128522752296, 2.0, 6.0)
# ('Restaurants', 'Mexican Restaurant', 'Alibertos Jr Fresh Mex', '2996 Telegraph Ave (at Ashby Ave), Berkeley, CA 94705', None, None, None, None, None, None, None, None, None)
# ('Restaurants', 'Mexican', 'Alibertos Jr. Mexican Food', '2996 Telegraph Ave Berkeley, CA 94705', 0.5927000237150958, None, None, None, None, 0.5927000237150958, 3.857098759934527, 3.5, 45.0)
# ('Restaurants', 'Restaurant', 'Alice Street Bakery Caf', '251 10th St (Alice), Oakland, CA 94607', 0.6512507883589609, 0.5884522589746293, 8.110053894268333, 7.2, 12.0, 0.7140493177432926, 4.127695976260195, 4.5, 208.0)
# ('Restaurants', 'Chinese Restaurant', "Alice's Restaurant", '1599 Sanchez St (at 29th St), San Francisco, CA 94131', 0.5966414084420353, 0.5586774893744263, 8.029551467421406, 7.5, 48.0, 0.6346053275096444, 3.9505435438279664, 4.0, 328.0)
# ('Bars', 'American (New), American (Traditional), Cocktail Bars', 'Aliment', '786 Bush St San Francisco, CA 94108', 0.6437092634865879, None, None, None, None, 0.6437092634865879, 3.970844442590472, 4.0, 797.0)
# ...
# ('Restaurants', 'Cafes, Halal, Mediterranean', 'Z Zoul Cafe', '295 Eddy St San Francisco, CA 94102', 0.6886873349653418, None, None, None, None, 0.6886873349653418, 4.071141201919123, 4.5, 135.0)
# ('Restaurants', 'Pizzeria', 'Za Pizza', '1919 Hyde St (btwn Green St & Delgado Pl), San Francisco, CA 94109', 0.709250551240833, 0.771234837079305, 8.604245497439093, 8.9, 264.0, 0.6472662654023611, 3.978776213636867, 4.0, 1224.0)
# ('Restaurants', 'Mediterranean Restaurant', "Za'atar", '1750 Cesar Chavez, San Francisco, CA 94124', 0.6985584724510164, None, None, None, None, 0.6985584724510164, 4.093152886016526, 4.5, 161.0)
# ('Restaurants', 'Thai', 'Zabb Thai Cuisine', '4440 Mission St San Francisco, CA 94112', 0.6352758971561807, None, None, None, None, 0.6352758971561807, 3.9520388494344663, 4.0, 349.0)
# ('Restaurants', 'Pizzeria', "Zachary's Chicago Pizza", '5801 College Ave (at Oak Grove Ave), Oakland, CA 94618', 0.8540836833045009, 0.8486542231657042, 8.813565285589926, 9.0, 621.0, 0.8595131434432978, 4.4520662713305335, 4.5, 3954.0)
# ('Restaurants', 'Pizzeria', "Zachary's Chicago Pizza", '3917 Grand Ave (Boulevard Way), Oakland, CA 94610', 0.6115575768534086, 0.6115575768534086, 8.172524038866824, 8.2, 12.0, None, None, None, None)
# ('Restaurants', 'Indian Restaurant', 'Zaika', '1445 Dwight Way, Berkeley, CA 94702', None, None, None, None, None, None, None, None, None)
# ('Restaurants', 'Indian', 'Zaika', '200 King St San Francisco, CA 94107', 0.6149725982548618, None, None, None, None, 0.6149725982548618, 3.90676445201071, 5.0, 1.0)
# ('Restaurants', 'Indian Restaurant', 'Zaika Indian Cuisine', '737 3rd St, San Francisco, CA 94107', 0.6191134767090226, None, None, None, None, 0.6191134767090226, 3.915998211397712, 4.0, 51.0)
# ('Restaurants', 'Beer, Wine & Spirits, Delis, Sandwiches', "Zain's Liquor", '34 3rd St San Francisco, CA 94103', 0.5283544380415678, None, None, None, None, 0.5283544380415678, 3.7136143127810426, 3.0, 92.0)
# ('Restaurants', 'Barbeque, Buffets, Korean', 'Zajang Grill', '852 Clement St San Francisco, CA 94118', 0.6413007644379131, None, None, None, None, 0.6413007644379131, 3.965473722115222, 4.5, 40.0)
# ('Restaurants', 'Sandwiches', "Zak's Snacks", '1865 Euclid Ave Berkeley, CA 94709', 0.6831720162197875, None, None, None, None, 0.6831720162197875, 4.058842573306179, 5.0, 57.0)
# ('Bars', 'Cocktail Bar, Fast Food Restaurant, Lounge', 'Zam Zam', '1633 Haight St (at Clayton St), San Francisco, CA 94117', 0.5858956906964022, 0.5350442266482801, 7.965653911560795, 7.7, 139.0, 0.6367471547445244, 3.955319611890417, 4.0, 400.0)
# ('Restaurants', 'Indian Restaurant, Pizzeria', 'Zante Pizza', '3489 Mission St (at 30th St), San Francisco, CA 94110', 0.5499371972225019, 0.5499371972225019, 8.005920227313464, 7.7, 97.0, None, None, None, None)
# ('Restaurants', 'Indian, Pizza', 'Zante Pizza & Indian Cuisine', '3489 Mission St San Francisco, CA 94110', 0.4749752403241934, None, None, None, None, 0.4749752403241934, 3.5945838525901275, 3.5, 1129.0)
# ('Bars', 'Bars', 'Zanzi Oakland', '19 Grand Ave Oakland, CA 94612', 0.612512366184025, None, None, None, None, 0.612512366184025, 3.901278371887913, 3.5, 2.0)
# ('Restaurants', 'Japanese, Sushi Bars', 'Zaoh Restaurant', '1555 Mission St San Francisco, CA 94103', 0.6352448860739365, None, None, None, None, 0.6352448860739365, 3.951969697713414, 4.0, 348.0)
# ('Bars, Restaurants', 'Bars, Mexican', "Zapata's Mexican Food & Taqueria", '549 W Julian St San Jose, CA 95110', 0.4717631342375621, None, None, None, None, 0.4717631342375621, 3.5874211659626867, 3.0, 186.0)
# ('Restaurants', 'Korean, Noodles, Soup', 'Zazang Korean Noodles', '2340 Geary Blvd San Francisco, CA 94115', 0.5020103537211588, None, None, None, None, 0.5020103537211588, 3.654869546766212, 3.5, 555.0)
# ('Restaurants', 'American Restaurant, French Restaurant', 'Zazie', '941 Cole St (btwn Parnassus Ave & Carl St), San Francisco, CA 94117', 0.7691526942133946, 0.8843143677763206, 8.909980076414953, 9.0, 1479.0, 0.6539910206504687, 3.993771768948351, 4.0, 5003.0)
# ('Restaurants', 'Café, Coffee Shop, Restaurant', 'Zazzi Foods', '1398 University Ave, Berkeley, CA 94702', None, None, None, None, None, None, None, None, None)
# ('Bars, Restaurants', 'Beer Garden, Burger Joint, Dive Bar', 'Zeitgeist', '199 Valencia St (at Duboce Ave), San Francisco, CA 94103', 0.6232158975120131, 0.7934167538749025, 8.66421903067342, 8.7, 2484.0, 0.4530150411491238, 3.545614727435182, 3.5, 2712.0)
# ('Bars, Restaurants', 'Cocktail Bar, Lounge, Restaurant', "Zeki's Bar", '1319 California St (at Leavenworth), San Francisco, CA 94109', 0.5851919890394841, 0.538228475383958, 7.974263205750081, 7.8, 203.0, 0.6321555026950102, 3.9450806708822737, 4.0, 261.0)
# ('Restaurants', 'Sandwiches, Soul Food', 'Zellas Soulful Kitchen', '499 14th St Ste 117 Oakland, CA 94612', 0.6580690748998234, None, None, None, None, 0.6580690748998234, 4.002865436420731, 4.5, 69.0)
# ('Restaurants', 'American (New)', 'Zellerbach Cafe', '101 Zellerbach Hall Berkeley, CA 94720', 0.592152763563052, None, None, None, None, 0.592152763563052, 3.855878422602242, 1.5, 7.0)
# ('Restaurants', 'Thai', 'Zen Yai Thai Restaurant', '771 Ellis St San Francisco, CA 94109', 0.6437435037534844, None, None, None, None, 0.6437435037534844, 3.970920795081706, 4.0, 800.0)
# ('Restaurants', 'Restaurant', 'Zero Zero', '826 Folsom St (btwn 4th St & 5th St), San Francisco, CA 94107', 0.7561766275351819, 0.7561766275351819, 8.563532422961996, 8.6, 1940.0, None, None, None, None)
# ('Restaurants', 'Halal Restaurant, Mediterranean Restaurant, Middle Eastern Restaurant', 'Zeugma Kebab', '889 S Almaden Ave, San Jose, CA 95110', None, None, None, None, None, None, None, None, None)
# ('Restaurants', 'Breakfast & Brunch, Mediterranean, Turkish', 'Zevi Cafe and Bistro', '67 5th St San Francisco, CA 94103', 0.6406774398472113, None, None, None, None, 0.6406774398472113, 3.964083768424416, 4.5, 39.0)
# ('Restaurants', 'American (New), Burgers, Halal', "Ziggy's Burgers", '21 Drumm St San Francisco, CA 94111', 0.4957002007744016, None, None, None, None, 0.4957002007744016, 3.64079851458052, 3.5, 645.0)
# ('Restaurants', 'Café, Restaurant', 'Zing Cafe', '3051 Adeline St (Essex), Berkeley, CA 94703', 0.6318792181829782, 0.5715355170123113, 8.064315881830428, 7.0, 18.0, 0.6922229193536452, 4.079025213945902, 4.5, 144.0)
# ('Bars, Restaurants', 'Cocktail Bars, Italian, Jazz & Blues', 'Zingari Ristorante & Jazz Room', '501 Post St San Francisco, CA 94102', 0.4889792114887334, None, None, None, None, 0.4889792114887334, 3.6258113570018873, 3.5, 763.0)
# ('Restaurants', 'Restaurant', 'Zino', '2086 Allston Way, Berkeley, CA 94704', 0.585644738373307, None, None, None, None, 0.585644738373307, 3.841366154407974, 3.5, 63.0)
# ('Restaurants', 'Ethiopian, Grocery', 'Zion Market', '2876 Telegraph Ave Oakland, CA 94609', 0.6145320286440189, None, None, None, None, 0.6145320286440189, 3.905782024290413, 4.0, 8.0)
# ('Restaurants', 'Delis', 'Zippis Deli', '2225 Webster St Oakland, CA 94612', 0.6010565327321645, None, None, None, None, 0.6010565327321645, 3.8757329686979807, 2.5, 7.0)
# ('Bars', 'Cocktail Bar, Restaurant, Tiki Bar', 'Zombie Village', '441 Jones St, San Francisco, CA 94102', 0.631422778966336, 0.6294192791890209, 8.22081695279837, 8.3, 114.0, 0.6334262787436513, 3.947914378849752, 4.0, 294.0)
# ('Bars', 'Night Club, Speakeasy', 'ZombieLand', '693 39th St, Oakland, CA 94609', None, None, None, None, None, None, None, None, None)
# ('Restaurants', 'Mexican Restaurant', 'Zona Rosa', '1411 the Alameda (at Lenzen Ave), San Jose, CA 95126', 0.7284929017107654, 0.7284929017107654, 8.488683578018616, 9.0, 112.0, None, None, None, None)
# ('Restaurants', 'Burrito Restaurant, Latin American Restaurant, Taco Restaurant', 'Zona Rosa', '1797 Haight St (at Shrader St.), San Francisco, CA 94117', 0.5601393731064936, 0.5601393731064936, 8.03350398123695, 7.4, 39.0, None, None, None, None)
# ('Restaurants', 'Mexican', 'Zona Rosa', '1411 The Alameda San Jose, CA 95126', 0.6482308171545261, None, None, None, None, 0.6482308171545261, 3.980927070971705, 4.0, 1401.0)
# ('Bars, Restaurants', 'American Restaurant, Sports Bar', 'Zone 8 Sports Bar & Grill', '1887 Matrix Blvd (at Airport Pkwy), San Jose, CA 95110', 0.4417825733614761, 0.4685650979803016, 7.7859134378543295, 6.4, 50.0, 0.4150000487426506, 3.460844962549341, 3.0, 332.0)
# ('Restaurants', 'American (New), Gluten-Free, Italian', 'Zoodle Hot Bar', '2353 E 12th St Oakland, CA 94601', 0.6166143124019616, None, None, None, None, 0.6166143124019616, 3.9104253161448224, 4.5, 4.0)
# ('Restaurants', 'French, Italian', 'Zuni Caf', '1658 Market St San Francisco, CA 94102', 0.4516071082566845, None, None, None, None, 0.4516071082566845, 3.5424751729407085, 3.5, 2938.0)
# ('Restaurants', 'American Restaurant, Italian Restaurant, New American Restaurant', 'Zuni Cafe', '1658 Market St (at Rose St), San Francisco, CA 94102', 0.7477872292179903, 0.7477872292179903, 8.540849899020154, 8.6, 1127.0, None, None, None, None)
# ('Restaurants', 'Japanese, Salad, Sushi Bars', 'Zushi Puzzle', '1910 Lombard St San Francisco, CA 94123', 0.648126724634582, None, None, None, None, 0.648126724634582, 3.9806949546964288, 4.0, 1380.0)
# ('Restaurants', 'American Restaurant, Mediterranean Restaurant', 'Zut', '1820 4th St, Berkeley, CA 94710', 0.5821916378106589, 0.5821916378106589, 8.093126972447067, 8.0, 150.0, None, None, None, None)
# ('Restaurants', 'Mediterranean', 'Zut On Fourth', '1820 4th St Berkeley, CA 94710', 0.5204574382388102, None, None, None, None, 0.5204574382388102, 3.696004765226081, 3.5, 366.0)
# ('Restaurants', 'Korean Restaurant', 'Zzan', '643 Post St, San Francisco, CA 94109', 0.5850156304923165, 0.5300784312616424, 7.952227826817998, 7.5, 87.0, 0.6399528297229906, 3.962467957767207, 4.0, 542.0)
# ('Restaurants', 'Latin American', 'alChile! Kitchen', 'San Francisco, CA 94102', 0.6138026315171355, None, None, None, None, 0.6138026315171355, 3.904155539079179, 4.0, 2.0)
# ('Restaurants', 'Bubble Tea, Sandwiches', 'b&b - Banh Mi & Boba', '1634 Irving St San Francisco, CA 94122', 0.6345392765012261, None, None, None, None, 0.6345392765012261, 3.950396256452653, 4.0, 326.0)
# ('Bars', 'Bar', 'baR/GA', '35 S Park St, San Francisco, CA 94107', None, None, None, None, None, None, None, None, None)
# ('Restaurants', 'Sandwiches, Vietnamese', 'banh mi & Roll Factory', '1814 Euclid Ave Berkeley, CA 94709', 0.6219262625150923, None, None, None, None, 0.6219262625150923, 3.922270452331111, 4.0, 83.0)
# ('Bars', 'Wine Bars', 'cc2', '1301 Mission St San Francisco, CA 94103', 0.6163831621833562, None, None, None, None, 0.6163831621833562, 3.90990987346171, 5.0, 2.0)
# ('Restaurants', 'American (New), Modern European', 'de Young Caf', '50 Hagiwara Tea Garden Dr Golden Gate Park San Francisco, CA 94118', 0.4235771877798535, None, None, None, None, 0.4235771877798535, 3.4799711549684416, 3.0, 305.0)
# ('Restaurants', 'Mexican Restaurant, Sushi Restaurant', 'el Mazatleco Mexican & seafood', '782 N 13th St, San Jose, CA 95112', None, None, None, None, None, None, None, None, None)
# ('Restaurants', 'Sushi Bars', 'iKU Sushi', '120 Montgomery St San Francisco, CA 94104', 0.6232562232163217, None, None, None, None, 0.6232562232163217, 3.925236136362957, 4.0, 100.0)
# ('Restaurants', 'American (New), Barbeque, Hawaiian', 'iLava Hawaiian Barbecue', '1446 High St Oakland, CA 94601', 0.6317426624336073, None, None, None, None, 0.6317426624336073, 3.94416007693554, 4.0, 251.0)
# ('Restaurants', 'Barbeque, Fast Food, Hawaiian', 'iLava Hawaiian Barbecue Adeline', '1446 High St Oakland, CA 94608', 0.6353117877022303, None, None, None, None, 0.6353117877022303, 3.9521188818889703, 5.0, 16.0)
# ('Restaurants', 'Asian Restaurant, Bubble Tea Shop, Chinese Restaurant', 'iNoodle', '1650 Holloway Ave, San Francisco, CA 94132', 0.5617359077159568, None, None, None, None, 0.5617359077159568, 3.7880517690768367, 2.5, 31.0)
# ('Restaurants', 'Pizza', 'iSlice - San Jose', '1751 N First St Ste 20 San Jose, CA 95112', 0.6225297768077304, None, None, None, None, 0.6225297768077304, 3.9236162309687903, 4.5, 12.0)
# ('Restaurants', 'Food Stands', 'iTea House', '428 11th St San Francisco, CA 94103', 0.6150928968502459, None, None, None, None, 0.6150928968502459, 3.907032706270445, 4.5, 2.0)
# ('Restaurants', 'Thai', 'iThai', '720 Post St San Francisco, CA 94109', 0.5110779582654055, None, None, None, None, 0.5110779582654055, 3.6750894299395327, 3.5, 451.0)
# ('Bars', 'Bars, Italian', 'il Cilentano', '579 Columbus Ave San Francisco, CA 94133', 0.7084378985402752, None, None, None, None, 0.7084378985402752, 4.115183052900129, 4.5, 190.0)
# ('Restaurants', 'Cafes', 'im moment kaffee', '5254 College Ave Oakland, CA 94618', 0.6587730696117259, None, None, None, None, 0.6587730696117259, 4.004435276697713, 5.0, 35.0)
# ('Restaurants', 'Eritrean, Food Trucks, Irish', 'ireTrea', 'San Francisco, CA 94109', 0.6209221104495829, None, None, None, None, 0.6209221104495829, 3.920031290118669, 4.0, 71.0)
# ('Restaurants', 'Pizza', 'kabuki', '123 Main St Ste 200 San Francisco, CA 94105', 0.6123846215469653, None, None, None, None, 0.6123846215469653, 3.9009935136737326, 3.0, 1.0)
# ('Restaurants', 'Gluten-Free, Hawaiian', 'lulubowls', '60 Morris St San Francisco, CA 94107', 0.5872181687529419, None, None, None, None, 0.5872181687529419, 3.844874752329545, 2.0, 11.0)
# ('Restaurants', 'Hawaiian', 'lulubowls', '949 Ruff Dr San Jose, CA 95110', 0.6066381522780968, None, None, None, None, 0.6066381522780968, 3.8881794416982047, 3.0, 6.0)
# ('Bars, Restaurants', 'Cocktail Bars, French, Vietnamese', 'lyse Restaurant', '151 S 2nd St San Jose, CA 95113', 0.7632074317371335, None, None, None, None, 0.7632074317371335, 4.237313827052654, 4.5, 439.0)
# ('Restaurants', 'Caterers, Gluten-Free, Korean', 'moonbowls', '60 Morris St San Francisco, CA 94107', 0.6269401302688387, None, None, None, None, 0.6269401302688387, 3.933450893618833, 4.0, 155.0)
# ('Restaurants', 'Caterers, Gluten-Free, Korean', 'moonbowls', '5325 Adeline St Oakland, CA 94608', 0.601799822724864, None, None, None, None, 0.601799822724864, 3.877390433659421, 3.5, 24.0)
# ('Restaurants', 'Breakfast & Brunch, Coffee & Tea', 'oaklandia cafe', '371 30th St Ste C100 Oakland, CA 94609', 0.756036423194409, None, None, None, None, 0.756036423194409, 4.221323169954493, 5.0, 141.0)
# ('Restaurants', 'Mediterranean, Salad, Sandwiches', 'opa cafe', '2401 Post St San Francisco, CA 94115', 0.7674065428736773, None, None, None, None, 0.7674065428736773, 4.246677439702324, 4.5, 468.0)
# ('Restaurants', 'Bakeries, Cafes', 'panaderia Sevilla', '1414 Fruitvale Ave Oakland, CA 94601', 0.6166143124019616, None, None, None, None, 0.6166143124019616, 3.9104253161448224, 4.5, 4.0)
# ('Restaurants', 'Pizzeria', 'passionepizza HQ', '2326 5th St (btwn Bancroft Way & Channing St), Berkeley, CA 94710', None, None, None, None, None, None, None, None, None)
# ('Bars', 'Cocktail Bars, Lounges', 'reception', '30 Otis St San Francisco, CA 94103', 0.6218048601692985, None, None, None, None, 0.6218048601692985, 3.9219997368144672, 4.5, 11.0)
# ('Restaurants', 'Salad, Vegetarian', 'sweetgreen', '831 Broadway Oakland, CA 94607', 0.5493999881989665, None, None, None, None, 0.5493999881989665, 3.760543858883808, 3.0, 65.0)
# ('Restaurants', 'Mexican', 'tacos de canasta', 'San Jose, CA', 0.6149725982548618, None, None, None, None, 0.6149725982548618, 3.90676445201071, 5.0, 1.0)
# ('Restaurants', 'Barbeque, Caterers, Pop-Up Restaurants', 'vana maria BBQ', '3226 25th St San Francisco, CA 94110', 0.6253893444326034, None, None, None, None, 0.6253893444326034, 3.929992790844004, 4.5, 16.0)
# ('Restaurants', 'Barbeque, Korean', 'yakiniQ SJ', '1783 W San Carlos St San Jose, CA 95128', 0.6449049105203969, None, None, None, None, 0.6449049105203969, 3.9735106201043, 4.0, 912.0)
# ('Restaurants', 'Chinese, Creperies, Desserts', 'yogo gelato', '601 Broadway San Francisco, CA 94133', 0.6099318355178045, None, None, None, None, 0.6099318355178045, 3.895524037505382, 2.5, 2.0)

# %%
create_data_by_station_table = """
CREATE TABLE IF NOT EXISTS data_by_station(
  ID INTEGER PRIMARY KEY AUTOINCREMENT, 
  Bike_Station_ID VARCHAR NOT NULL, 
  Bike_Station_Coordinates VARCHAR NOT NULL, 
  POI_API TEXT NOT NULL, 
  POI_Mean_Distance FLOAT NOT NULL,
  POI_FSQ_Distance FLOAT, 
  POI_Yelp_Distance FLOAT,
  POI_Query TEXT NOT NULL,
  POI_Categories TEXT NOT NULL,
  POI_Name VARCHAR NOT NULL, 
  POI_Address VARCHAR NOT NULL,
  POI_Mean_Bayesian_Adj_Rating_Norm FLOAT,
  POI_FSQ_Bayesian_Adj_Rating_Norm FLOAT,
  POI_FSQ_Bayesian_Adj_Rating FLOAT, 
  POI_FSQ_Rating FLOAT,
  POI_Yelp_Bayesian_Adj_Rating_Norm FLOAT,
  POI_Yelp_Bayesian_Adj_Rating FLOAT,
  POI_Yelp_Rating FLOAT,
  POI_Yelp_Num_Ratings FLOAT,
  FOREIGN KEY (POI_Name) REFERENCES data_by_business(POI_Name)
  FOREIGN KEY (POI_Address) REFERENCES data_by_business(POI_Address)
); 
"""

# %%
# Populate the new table with values from the .csv file 
DataByStation = pd.read_csv("../final_data/DataByStation.csv")
DataByStation.to_sql("data_by_station", connection, if_exists='replace', index=False)
# Out:
# 59329

# %%
cursor.execute('SELECT * from data_by_station')
SF_POI_by_station = cursor.fetchmany(10)
for row in SF_POI_by_station:
    print(row)
# Out:
# ('003d58af-e449-4800-aa6d-eb1bba8ad68d', '37.726266,-122.479462', 9.0, 'Both', 423.0, 418.0, 428.0, 'Restaurants', 'Sandwich Restaurant, Soup Restaurant, Vietnamese Restaurant', 'Ha Tien Cove', '1650 Holloway Ave, San Francisco, CA 94132', 0.5931111008807091, None, None, None, None, 0.5931111008807091, 3.858015422347776, 3.5, 44.0)
# ('003d58af-e449-4800-aa6d-eb1bba8ad68d', '37.726266,-122.479462', 9.0, 'FSQ', 297.0, 297.0, None, 'Restaurants', 'Poke Restaurant', 'Poke Bowl', '3251 20th Ave, San Francisco, CA 94132', 0.579709295832914, 0.579709295832914, 8.086415432571, 6.4, 9.0, None, None, None, None)
# ('003d58af-e449-4800-aa6d-eb1bba8ad68d', '37.726266,-122.479462', 9.0, 'FSQ', 295.0, 295.0, None, 'Restaurants', 'Restaurant', 'Quickly', '3251 20th Ave (Winston Dr), San Francisco, CA 94132', 0.5656261612420743, 0.5656261612420743, 8.048338680764102, 5.6, 9.0, None, None, None, None)
# ('003d58af-e449-4800-aa6d-eb1bba8ad68d', '37.726266,-122.479462', 9.0, 'FSQ', 295.0, 295.0, None, 'Restaurants', 'Bakery, Dessert Shop, French Restaurant', 'Cocola Bakery', '3251 20th Ave (inside Stonestown Galleria), San Francisco, CA 94132', 0.5675485322370796, 0.5675485322370796, 8.053536219904657, 7.3, 28.0, None, None, None, None)
# ('003d58af-e449-4800-aa6d-eb1bba8ad68d', '37.726266,-122.479462', 9.0, 'FSQ', 293.0, 293.0, None, 'Restaurants', 'Noodle Restaurant, Sushi Restaurant', 'Tosai', '3251 20th Ave, San Francisco, CA 94132', None, None, None, None, None, None, None, None, None)
# ('003d58af-e449-4800-aa6d-eb1bba8ad68d', '37.726266,-122.479462', 9.0, 'FSQ', 292.0, 292.0, None, 'Restaurants', 'Sushi Restaurant', 'Tokyo Express', '3251 20th Ave, San Francisco, CA 94132', 0.5713454053491408, 0.5713454053491408, 8.063801874485867, 7.4, 29.0, None, None, None, None)
# ('003d58af-e449-4800-aa6d-eb1bba8ad68d', '37.726266,-122.479462', 9.0, 'FSQ', 286.0, 286.0, None, 'Restaurants', 'Fast Food Restaurant, Pizzeria', 'Pizza Hut', '233 Winston Dr, San Francisco, CA 94132', None, None, None, None, None, None, None, None, None)
# ('003d58af-e449-4800-aa6d-eb1bba8ad68d', '37.726266,-122.479462', 9.0, 'Both', 512.5, 512.0, 513.0, 'Restaurants', 'Deli, Fast Food Restaurant', 'Subway', '595 Buckingham Way (20th Ave.), San Francisco, CA 94132', 0.5493797713887321, 0.5822651388964645, 8.093325698276441, 6.7, 10.0, 0.5164944038809998, 3.687167581013231, 2.5, 63.0)
# ('003d58af-e449-4800-aa6d-eb1bba8ad68d', '37.726266,-122.479462', 9.0, 'FSQ', 301.0, 301.0, None, 'Restaurants', 'Fast Food Restaurant, Pizzeria, Salad Restaurant', "Blaze Fast-Fire'd Pizza", '3251 20th Ave, San Francisco, CA 94132', None, None, None, None, None, None, None, None, None)
# ('003d58af-e449-4800-aa6d-eb1bba8ad68d', '37.726266,-122.479462', 9.0, 'Both', 463.5, 446.0, 481.0, 'Restaurants', 'American Restaurant, Burger Joint, Mexican Restaurant', 'Gold Coast Grill & Catering', '1650 Holloway Ave, San Francisco, CA 94132', 0.5795294303753292, None, None, None, None, 0.5795294303753292, 3.827729607656887, 3.5, 80.0)

# %% [markdown]
# # Look at the data before and after the join to validate your data.

# %%
# This code describes how to retrieve records from an SQLite database
# The cursor's .execute() method is used to run a SELECT query
# After the query is executed, .fetchall() is called to retrieve the results, which are returned as a list of tuples, where each tuple represents a row of data
# To make the process easier, a function called "execute_read_query" is created to simplify this process
def execute_read_query(connection, query):
    cursor = connection.cursor()
    result = None
    try:
        cursor.execute(query)
        result = cursor.fetchall()
        return result
    except Error as e:
        print(f"The error '{e}' occurred")

# %%
# Check if there are any empty Bike_Station_ID in data_by_station table
# If not, return 'none', otherwise, print the rows where Bike_Station_ID is empty 
select_no_bikestation = "SELECT * FROM data_by_station WHERE Bike_Station_ID IS NULL;"

Bike_Station_ID  = execute_read_query(connection, select_no_bikestation)

if not Bike_Station_ID:
    print('none') 
else:
    for station in Bike_Station_ID:
         print(station)
# Out:
# none

# %%
# Check if there are any empty Bike_Station_Coordinates in data_by_station table
# If not, return 'none', otherwise, print the rows where Bike_Station_ID is empty 
select_no_bikecoordinates = "SELECT * FROM data_by_station WHERE Bike_Station_Coordinates IS NULL;"

problem_rows  = execute_read_query(connection, select_no_bikecoordinates)

if not problem_rows:
    print('none') 
else:
    for row in problem_rows:
         print(row)
# Out:
# none

# %%
# Check if there are any empty POI_API in data_by_station table
# If not, return 'none', otherwise, print the rows where Bike_Station_ID is empty 
select_no_API = "SELECT * FROM data_by_station WHERE POI_API IS NULL;"

problem_rows  = execute_read_query(connection, select_no_API)

if not problem_rows:
    print('none') 
else:
    for row in problem_rows:
         print(station)
# Out:
# none

# %%
# Check if there are any empty cells in data_by_business table under columns that shouldn't 
# If not, return 'none', otherwise, print the problematic rows
select_nulls = "SELECT * FROM data_by_business WHERE POI_Query IS NULL UNION ALL SELECT * FROM data_by_business WHERE POI_Categories IS NULL UNION ALL SELECT * FROM data_by_business WHERE POI_Name IS NULL UNION ALL SELECT * FROM data_by_business WHERE POI_Address IS NULL;"

problem_rows  = execute_read_query(connection, select_nulls)

if not problem_rows:
    print('none') 
else:
    for row in problem_rows:
         print(station)
# Out:
# none

# %%
# See if the number of rows in data_by_business is the same as DataByBusiness.csv
count_rows = 'SELECT COUNT(*) FROM data_by_business;'
count_rows = execute_read_query(connection, count_rows)
print(count_rows)
# Out:
# [(9327,)]

# %%
# The two tables have the same number of rows 
DataByBusiness = pd.read_csv('../final_data/DataByBusiness.csv')
num_rows = len(DataByBusiness)
print(num_rows)
# Out:
# 9327

# %%
# See if the number of rows in data_by_station is the same as DataByStation.csv
count_rows = 'SELECT COUNT(*) FROM data_by_station;'
count_rows = execute_read_query(connection, count_rows)
print(count_rows)
# Out:
# [(59329,)]

# %%
# The two tables have the same number of rows 
DataByBusiness = pd.read_csv('../final_data/DataByStation.csv')
num_rows = len(DataByStation)
print(num_rows)
# Out:
# 59329

# %%
# This looks for rows where the same business is duplicated in data_by_business
# some restaurant names appear more than once due to several locations, but grouping by name and address should eliminate that issue
duplicate_rows = 'SELECT POI_Name, POI_Address, COUNT(*) FROM data_by_business GROUP BY POI_Name, POI_Address HAVING COUNT(*) > 1;'
problem_rows  = execute_read_query(connection, duplicate_rows)

if not problem_rows:
    print('none') 
else:
    for row in problem_rows:
         print(row)
# Out:
# none

# %%
# When grouping POI by stations, the same POI may appear for different stations. Also, the same POI_Name may appear for the same station if it's a chain and there is more than one near a station
# Grouping by Bike_station_ID, POI_Name, POI_Address should eliminate detecting false duplicates 
duplicate_rows = 'SELECT Bike_Station_ID, POI_Name, POI_Address, COUNT(*) FROM data_by_station GROUP BY Bike_station_ID, POI_Name, POI_Address HAVING COUNT(*) > 1;'
problem_rows  = execute_read_query(connection, duplicate_rows)

if not problem_rows:
    print('none') 
else:
    for row in problem_rows:
         print(row)
# Out:
# none
